# %% [markdown]
# ## Milestone 2B
# ## Task allocation
# The planned allocation of tasks are:
# * Gayatri:
#     * Autodiff class implementation and makefile
# * Morris:
#     * Forward mode implementation and elemental functions (sin, cos, tan, arcsin, arccos, arctan in diff.cpp)
#     * Implementation of Jacobian evaluation
# * Scarlett:
#     * Create test suite ("The repository should reflect at least 90% code coverage")
#     * Draft implementation of dual numbers and Newton's method
#
# ## Progress report
# Completed activities since the submission of Milestone1 include:
# * Gayatri:
#     * Overloading the basic operations
# * Morris:
#     * Appended description of root-finding and Newton's method to documentation for Milestone 2A
#     * Defined elemental functions in diff.cpp (with input and output of type AutoDiff)
# * Scarlett:
#     * Appened description of dual number implementation (nonlinear cases) to documentation for Milestone 2A
#
# Tasks for milestone 2: <br>
#
# 1. Makefile <br>
# 2. Test suite <br>
# 3. Autodiff class implementation <br>
# 4. Forward mode implementation using autodiff class <br>
#
# Pending tasks/extensions backlog:
#
# 1. Root finding implementation:
#     * Second derivative and Hessian matrix evaluation
#     * Jacobian matrix evaluation
# 2. Dual numbers implementation
#
# Outstanding questions:
#
# * Waiting for a response to @442 on Piazza to understand what test/implentation needs to be able to do
